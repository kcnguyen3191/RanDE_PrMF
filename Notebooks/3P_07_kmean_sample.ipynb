# %%
import sys, importlib
# "../" to go back one director
import sys
sys.path.append('../')
sys.path.append('../../')
sys.path.append('../../../')
import os
# import torch.nn as nn
# from Modules.Utils.Imports import *
# from Modules.Utils.JTNPDESolver import *
# from Modules.Utils.Gradient import Gradient
# from Modules.Utils.ModelWrapper import ModelWrapper
# from Modules.Models.BuildSurfaceFitter import *
# from torch.autograd import Variable
# import Modules.Utils.PDESolver as PDESolver
# import DataFormatter as DF

import numpy as np
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import Axes3D
from scipy.io import loadmat
import scipy.io
from scipy import integrate, interpolate
from scipy.sparse import spdiags
from scipy import sparse
import bisect
import matplotlib.colors as colors
import matplotlib.cm as cm
from Projects.Scripts.Plotters import *

# %%
path = os.getcwd()+'/NPY_Data/data_wider_3P_E2.npy'
data = np.load(path, allow_pickle=True).item()

x = data['x']
t = data['t']
t = t[:26]
U = data['u_noise']
U = U[:,:26]
# t = t/
X, T = np.meshgrid(x, t, indexing='ij')

shape = U.shape

# flatten for MLP
inputs = np.concatenate([X.reshape(-1)[:, None],
                         T.reshape(-1)[:, None]], axis=1)
outputs = U.reshape(-1)[:, None]

# %%
# Get data
u_data = outputs.reshape(shape)
x = data['x']
t = data['t']

# %%
# data

# %%
max_D_nodes = 20
max_rho_nodes = 20
max_K_nodes = 1

D_min = 0.0
D_max = 0.12
rho_min = 0.0
rho_max = 12.0
K_min = 1.0
K_max = 1.0

weights_mesh = data['pdf_mesh']

numX = len(x)
numT = len(t)
numData = numX*numT
numData = np.float(numData)

num_D_nodes = [5, 10, 20]
num_rho_nodes = [5, 10, 20]


#### Interpolation
load_file = 'PMF_Results_Interp_3P_E2/best_PMF.npy'     
best_results_Interp = np.load(load_file, allow_pickle=True).item()
        
# Interp_best_numDnode = best_numDnode
# Interp_best_numKnode = best_numKnode
# Interp_weights = best_weights
Interp_RSS = best_results_Interp['best_RSS']

D_vec = np.linspace(D_min, D_max, max_D_nodes)
rho_vec = np.linspace(rho_min, rho_max, max_rho_nodes)
K_vec = np.linspace(K_min, K_max, max_K_nodes)

num_D_node = best_results_Interp['best_numDnode']
num_rho_node = best_results_Interp['best_numRhonode']
weights = best_results_Interp['best_weights']
weights = weights.reshape((best_results_Interp['best_numDnode'],best_results_Interp['best_numRhonode']))

D_vec_idx = np.floor(np.linspace(0,max_D_nodes-1, num_D_node))
rho_vec_idx = np.floor(np.linspace(0,max_rho_nodes-1, num_rho_node))
D_vec_idx = D_vec_idx.astype(int)
rho_vec_idx = rho_vec_idx.astype(int)

D_vec = D_vec[D_vec_idx]
rho_vec = rho_vec[rho_vec_idx]
# Out:
# /var/folders/tf/124zrkp12d32s2b41mk0ps6h0000gn/T/ipykernel_34498/4284061387.py:17: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   numData = np.float(numData)

# %%
D_mesh, rho_mesh = np.meshgrid(D_vec, rho_vec, indexing='ij')

D_idx = np.arange(num_D_node)
rho_idx = np.arange(num_rho_node)
D_idx_mesh, rho_idx_mesh = np.meshgrid(D_idx, rho_idx, indexing='ij')

# %%
D_mesh = D_mesh.reshape((1,-1))
rho_mesh = rho_mesh.reshape((1,-1))

D_idx_mesh = D_idx_mesh.reshape((1,-1))
rho_idx_mesh = rho_idx_mesh.reshape((1,-1))

weights = weights.reshape((1,-1))
weights_cdf = np.cumsum(weights)


out_idx = np.zeros((100000,1))
for i in np.arange(100000):
    rand_num = np.random.uniform(low=0, high=1, size=1)
    less_rand = weights_cdf < rand_num[0]*weights_cdf[-1]
    out_idx[i] = sum(less_rand)
    
out_idx = out_idx.astype(np.int64)

# %%
D_coor = D_mesh[:,out_idx]
rho_coor = rho_mesh[:,out_idx]

# Rescale D and K to 0-1
# D_coor = (D_coor - D_min)/(D_max - D_min)
# K_coor = (K_coor - K_min)/(K_max - K_min)

# %%
count_map = np.zeros((num_D_node,num_rho_node))
for i in np.arange(100000):
    count_map[D_idx_mesh[:,out_idx[i]][0], rho_idx_mesh[:,out_idx[i]][0]] += 1

# %%
fig = plt.figure(figsize=(11,11))
ax = fig.add_subplot(3, 1, 1)
ax.contourf(count_map.T, interpolation='nearest')
# Out:
# /var/folders/tf/124zrkp12d32s2b41mk0ps6h0000gn/T/ipykernel_34498/4003352783.py:3: UserWarning: The following kwargs were not used by contour: 'interpolation'
#   ax.contourf(count_map.T, interpolation='nearest')

# %% [markdown]
# # Install a pip package in the current Jupyter kernel
# import sys
# !{sys.executable} -m pip install kneed

# %%
from kneed import KneeLocator
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

coor = np.concatenate((D_coor, rho_coor), axis=0).T
coor = coor[0,:,:]
scaler = StandardScaler()
scaled_features = scaler.fit_transform(coor)

max_n_clusters = 10

SSE = []
cluster_centers = {}

for i in np.arange(1,max_n_clusters+1):
    kmeans = KMeans(init="random",n_clusters=i,n_init=10,max_iter=300,random_state=42)
    kmeans.fit(scaled_features)
    cluster_centers[i] = kmeans.cluster_centers_
    SSE.append(kmeans.inertia_)
    
kl = KneeLocator(np.arange(1,max_n_clusters+1), SSE, curve="convex", direction="decreasing")
kl.elbow
# Out:
# 2

# %%
true_elbow = 3

prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
markers = ['x', 'o', 's', 'd', '^']
fig = plt.figure(figsize=(11,11))
ax = fig.add_subplot(2, 1, 1)

plt.plot(np.arange(max_n_clusters)[None,:][0]+1, SSE, '-', c=colors[0], linewidth=5)
plt.axvline(x = true_elbow, color = 'k', linewidth=5)
plt.axvline(x = kl.elbow, color = 'tab:red', linestyle='dashed', linewidth=5)
plt.xlabel('Number of Clusters', fontsize=14)
plt.ylabel('SSE', fontsize=14)
plt.legend(['Elbow plot','True','Predicted'])
plt.grid()
plt.title('Elbow plot \n True = %.0f, ' %true_elbow + 'Predicted = %.0f' %kl.elbow, fontsize=20)
plt.savefig('Figures/Elbow_3P_E2.pdf',bbox_inches='tight')

# %%
reverse_cluster_true = scaler.inverse_transform(cluster_centers[true_elbow])
reverse_cluster_pred = scaler.inverse_transform(cluster_centers[kl.elbow])

# %%
reverse_cluster_true, reverse_cluster_pred
# Out:
# (array([[0.02641918, 9.31999312],
#         [0.08935034, 1.48479944],
#         [0.02612871, 5.64107307]]),
#  array([[0.02615319, 7.78095096],
#         [0.08896091, 1.49524651]]))

# %% [markdown]
# max_D_nodes = 20
# max_rho_nodes = 20
# max_K_nodes = 1
#
# D_min = 0.0
# D_max = 0.12
# rho_min = 0.0
# rho_max = 12.0
# K_min = 1.0
# K_max = 1.0
#
# weights_mesh = data['pdf_mesh']
#
# # plot heatmap of residuals
# fig = plt.figure(figsize=(11,11))
# ax = fig.add_subplot(3, 1, 1)
# ax.contourf(np.reshape(data['D_params'],weights_mesh.shape), np.reshape(data['rho_params'],weights_mesh.shape), weights_mesh)
# plt.scatter(reverse_cluster_true[:,0], reverse_cluster_true[:,1], c ="slategrey",
#             linewidths = 0.5,
#             marker ="s",
#             edgecolor ="k",
#             s = 150)
# plt.scatter(reverse_cluster_pred[:,0], reverse_cluster_pred[:,1], c ="forestgreen",
#             linewidths = 0.5,
#             marker ="^",
#             edgecolor ="k",
#             s = 150)
# ax.set_xlabel('D')
# ax.set_ylabel('rho')
# ax.set_title('True Mesh')
# # fig.colorbar(res)
# plt.savefig('Figures/ClusterCenters_TrueMesh_3P_E2.pdf',bbox_inches='tight')
#
# numX = len(x)
# numT = len(t)
# numData = numX*numT
# numData = np.float(numData)
#
# num_D_nodes = [5, 10, 20]
# num_rho_nodes = [5, 10, 20]
#
#
# #### Interpolation
# load_file = 'PMF_Results_Interp_3P_E2/best_PMF.npy'
# best_results_Interp = np.load(load_file, allow_pickle=True).item()
#
# # Interp_best_numDnode = best_numDnode
# # Interp_best_numKnode = best_numKnode
# # Interp_weights = best_weights
# Interp_RSS = best_results_Interp['best_RSS']
#
# D_vec = np.linspace(D_min, D_max, max_D_nodes)
# rho_vec = np.linspace(rho_min, rho_max, max_rho_nodes)
# K_vec = np.linspace(K_min, K_max, max_K_nodes)
#
# num_D_node = best_results_Interp['best_numDnode']
# num_rho_node = best_results_Interp['best_numRhonode']
# weights = best_results_Interp['best_weights']
# weights = weights.reshape((best_results_Interp['best_numDnode'],best_results_Interp['best_numRhonode']))
#
# D_vec_idx = np.floor(np.linspace(0,max_D_nodes-1, num_D_node))
# rho_vec_idx = np.floor(np.linspace(0,max_rho_nodes-1, num_rho_node))
# D_vec_idx = D_vec_idx.astype(int)
# rho_vec_idx = rho_vec_idx.astype(int)
#
# D_vec = D_vec[D_vec_idx]
# rho_vec = rho_vec[rho_vec_idx]
#
# D_mesh, rho_mesh = np.meshgrid(D_vec, rho_vec, indexing='ij')
#
# delta_D = D_vec[1]-D_vec[0]
# delta_rho = rho_vec[1]-rho_vec[0]
#
# # plot heatmap of residuals
# fig = plt.figure(figsize=(11,11))
# ax = fig.add_subplot(3, 1, 2)
# # ax.contourf(D_mesh, rho_mesh, weights)
#
# import seaborn as sns
#
# sns.heatmap(weights.T)
#
# delta_D = D_vec[1]-D_vec[0]
# delta_rho = rho_vec[1]-rho_vec[0]
# reverse_cluster_true[:,0] = (reverse_cluster_true[:,0] - D_min)/(D_max - D_min)*len(D_vec)
# reverse_cluster_true[:,1] = (reverse_cluster_true[:,1] - rho_min)/(rho_max - rho_min)*len(rho_vec)
#
# # res = ax.imshow(weights.T, aspect='auto',extent=[D_min-0.5*delta_D, D_max+0.5*delta_D, rho_max+0.5*delta_rho, rho_min-0.5*delta_rho], alpha=1)
# plt.scatter(reverse_cluster_true[:,0], reverse_cluster_true[:,1], c ="slategrey",
#             linewidths = 0.5,
#             marker ="s",
#             edgecolor ="k",
#             s = 150)
# plt.scatter(reverse_cluster_pred[:,0], reverse_cluster_pred[:,1], c ="forestgreen",
#             linewidths = 0.5,
#             marker ="^",
#             edgecolor ="k",
#             s = 150)
# ax.set_xlabel('D')
# ax.set_ylabel('rho')
# ax.set_title('Predicted Mesh: Interpolation, Error = %.4f' %Interp_RSS)
# plt.savefig('Figures/ClusterCenters_PredMesh_3P_E2.pdf',bbox_inches='tight')

# %%
# plot heatmap of residuals
fig1, ax1 = Plot_PDF(D_mesh,
                     rho_mesh,
                     weights,
                     x_label='Diffusion', 
                     y_label='Growth rate',
                     title='Predicted cluster centers',
                     save_path=None)

figure_mods = {}
figure_mods['color'] = "slategrey"
figure_mods['linewidths'] = 0.5
figure_mods['marker'] = 's'
figure_mods['edgecolor'] = 'k'
figure_mods['size'] = 150
figure_mods['legend_list'] = ['_','_','_','_','_','_','_','_','Cluster centers']

Plot_CentersOnPDF(PDF_fig=fig1,
                  PDF_ax=ax1,
                  param1_center=reverse_cluster_pred[:,0],
                  param2_center=reverse_cluster_pred[:,1],
                  param1_vec=D_vec,
                  param2_vec=rho_vec,
                  figure_mods=figure_mods,
                  save_path='Figures/ClusterCenters_PredMesh_3P_E2.pdf')

# figure_mods['marker'] = '^'
# figure_mods['color'] = "tab:green"

# Plot_CentersOnPDF(PDF_fig=fig1,
#                   PDF_ax=ax1,
#                   param1_center=reverse_cluster_true[:,0],
#                   param2_center=reverse_cluster_true[:,1],
#                   param1_vec=D_vec,
#                   param2_vec=rho_vec,
#                   figure_mods=figure_mods,
#                   save_path='Figures/ClusterCenters_PredMesh_3P_E2.pdf')
# Out:
# /Users/kyle/Library/CloudStorage/GoogleDrive-kcnguye2@ncsu.edu/My Drive/Projects/PMF_Project/Projects/RDE_Fisher_Dp/../../Projects/Scripts/Plotters.py:312: UserWarning: The handle <matplotlib.collections.PathCollection object at 0x7fba143e5d60> has a label of '_' which cannot be automatically added to the legend.
#   PDF_ax.legend(figure_mods['legend_list'],loc='upper right')
# /Users/kyle/Library/CloudStorage/GoogleDrive-kcnguye2@ncsu.edu/My Drive/Projects/PMF_Project/Projects/RDE_Fisher_Dp/../../Projects/Scripts/Plotters.py:312: UserWarning: The handle <matplotlib.collections.PathCollection object at 0x7fba143e5dc0> has a label of '_' which cannot be automatically added to the legend.
#   PDF_ax.legend(figure_mods['legend_list'],loc='upper right')
# /Users/kyle/Library/CloudStorage/GoogleDrive-kcnguye2@ncsu.edu/My Drive/Projects/PMF_Project/Projects/RDE_Fisher_Dp/../../Projects/Scripts/Plotters.py:312: UserWarning: The handle <matplotlib.collections.PathCollection object at 0x7fba143d6070> has a label of '_' which cannot be automatically added to the legend.
#   PDF_ax.legend(figure_mods['legend_list'],loc='upper right')
# /Users/kyle/Library/CloudStorage/GoogleDrive-kcnguye2@ncsu.edu/My Drive/Projects/PMF_Project/Projects/RDE_Fisher_Dp/../../Projects/Scripts/Plotters.py:312: UserWarning: The handle <matplotlib.collections.PathCollection object at 0x7fba143d62b0> has a label of '_' which cannot be automatically added to the legend.
#   PDF_ax.legend(figure_mods['legend_list'],loc='upper right')
# /Users/kyle/Library/CloudStorage/GoogleDrive-kcnguye2@ncsu.edu/My Drive/Projects/PMF_Project/Projects/RDE_Fisher_Dp/../../Projects/Scripts/Plotters.py:312: UserWarning: The handle <matplotlib.collections.PathCollection object at 0x7fba143d6580> has a label of '_' which cannot be automatically added to the legend.
#   PDF_ax.legend(figure_mods['legend_list'],loc='upper right')
# /Users/kyle/Library/CloudStorage/GoogleDrive-kcnguye2@ncsu.edu/My Drive/Projects/PMF_Project/Projects/RDE_Fisher_Dp/../../Projects/Scripts/Plotters.py:312: UserWarning: The handle <matplotlib.collections.PathCollection object at 0x7fba143d6850> has a label of '_' which cannot be automatically added to the legend.
#   PDF_ax.legend(figure_mods['legend_list'],loc='upper right')
# /Users/kyle/Library/CloudStorage/GoogleDrive-kcnguye2@ncsu.edu/My Drive/Projects/PMF_Project/Projects/RDE_Fisher_Dp/../../Projects/Scripts/Plotters.py:312: UserWarning: The handle <matplotlib.collections.PathCollection object at 0x7fba143d6af0> has a label of '_' which cannot be automatically added to the legend.
#   PDF_ax.legend(figure_mods['legend_list'],loc='upper right')
# /Users/kyle/Library/CloudStorage/GoogleDrive-kcnguye2@ncsu.edu/My Drive/Projects/PMF_Project/Projects/RDE_Fisher_Dp/../../Projects/Scripts/Plotters.py:312: UserWarning: The handle <matplotlib.collections.PathCollection object at 0x7fba143d6d60> has a label of '_' which cannot be automatically added to the legend.
#   PDF_ax.legend(figure_mods['legend_list'],loc='upper right')
# (<Figure size 1100x1100 with 1 Axes>,
#  <AxesSubplot:title={'center':'Predicted cluster centers'}, xlabel='Diffusion', ylabel='Growth rate'>)
